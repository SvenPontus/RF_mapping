# %%
import pandas as pd
path = "/local/data2/LIA_LIU/testing_pontus-testing-2024-10-18/dlc-models-pytorch/iteration-0/testing_pontusOct18-trainset95shuffle1/train/learning_stats.csv"
df = pd.read_csv(path)
df
# Out:
#      step  losses/eval.bodypart_heatmap  losses/eval.bodypart_locref  \
# 0       1                           NaN                          NaN
# 1       2                           NaN                          NaN
# 2       3                           NaN                          NaN
# 3       4                           NaN                          NaN
# 4       5                           NaN                          NaN
# ..    ...                           ...                          ...
# 195   196                           NaN                          NaN
# 196   197                           NaN                          NaN
# 197   198                           NaN                          NaN
# 198   199                           NaN                          NaN
# 199   200                      0.000029                     0.044083
#
#      losses/eval.bodypart_total_loss  losses/eval.total_loss  \
# 0                                NaN                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   step                                  200 non-null    int64
#  1   losses/eval.bodypart_heatmap          20 non-null     float64
#  2   losses/eval.bodypart_locref           20 non-null     float64
#  3   losses/eval.bodypart_total_loss       20 non-null     float64
#  4   losses/eval.total_loss                20 non-null     float64
#  5   losses/train.bodypart_heatmap         200 non-null    float64
#  6   losses/train.bodypart_locref          200 non-null    float64
#  7   losses/train.bodypart_total_loss      200 non-null    float64
#  8   losses/train.total_loss               200 non-null    float64
#  9   metrics/test.mAP                      20 non-null     float64
# ...

# %%
df.describe()
# Out:
#              step  losses/eval.bodypart_heatmap  losses/eval.bodypart_locref  \
# count  200.000000                     20.000000                    20.000000
# mean   100.500000                      0.000060                     0.060984
# std     57.879185                      0.000039                     0.017685
# min      1.000000                      0.000028                     0.042410
# 25%     50.750000                      0.000036                     0.048025
# 50%    100.500000                      0.000048                     0.055887
# 75%    150.250000                      0.000061                     0.067701
# max    200.000000                      0.000186                     0.105873
#
#        losses/eval.bodypart_total_loss  losses/eval.total_loss  \
# count                        20.000000               20.000000
# mean                          0.001554                0.001554
# std                           0.000458                0.000458
# ...

# %%
import pandas as pd

result_file = "/local/data2/LIA_LIU/testing_pontus-testing-2024-10-18/videos/squaretestDLC_Resnet50_testing_pontusOct18shuffle1_snapshot_200.h5"

df = pd.read_hdf(result_file)
print(df)
# Out:
# scorer    DLC_Resnet50_testing_pontusOct18shuffle1_snapshot_200              \
# bodyparts                                                   FR1
# coords                                                        x           y
# 0                                                 797.028564     319.772095
# 1                                                 797.095642     319.675720
# 2                                                 797.096863     319.597748
# 3                                                 797.087280     319.642548
# 4                                                 797.029053     319.609375
# ..                                                       ...            ...
# 958                                               756.924744     419.002167
# 959                                               735.816040     325.759979
# 960                                               756.987732     419.056061
# ...

# %%
df.describe().transpose()
# Out:
#                                                                                count  \
# scorer                                                bodyparts    coords
# DLC_Resnet50_testing_pontusOct18shuffle1_snapshot_200 FR1          x           963.0
#                                                                    y           963.0
#                                                                    likelihood  963.0
#                                                       FR2          x           963.0
#                                                                    y           963.0
#                                                                    likelihood  963.0
#                                                       FG1          x           963.0
#                                                                    y           963.0
#                                                                    likelihood  963.0
# ...

# %%
import pandas as pd

result_file = "/local/data2/LIA_LIU/arvidh_h5/2-2k7-120-handDLC_resnet50_test5 May2shuffle1_70000.h5"

df = pd.read_hdf(result_file)
print(df)
# Out:
# scorer    DLC_resnet50_test5 May2shuffle1_70000                         \
# bodyparts                                   FR1
# coords                                        x           y likelihood
# 0                                    876.314880  329.061798   0.026450
# 1                                    876.596741  329.026978   0.026710
# 2                                    877.028320  328.957397   0.026916
# 3                                    876.621948  329.226196   0.025435
# 4                                    876.529114  329.046143   0.024527
# ..                                          ...         ...        ...
# 845                                 1082.813843  144.164658   0.225126
# 846                                 1077.733032  146.096207   0.154784
# 847                                 1076.430908  145.933792   0.259142
# 848                                 1077.947021  144.263901   0.244790
# ...

# %%
df.describe().transpose()
# Out:
#                                                                count  \
# scorer                                bodyparts    coords
# DLC_resnet50_test5 May2shuffle1_70000 FR1          x           850.0
#                                                    y           850.0
#                                                    likelihood  850.0
#                                       FR2          x           850.0
#                                                    y           850.0
#                                                    likelihood  850.0
#                                       FG1          x           850.0
#                                                    y           850.0
#                                                    likelihood  850.0
#                                       FG2          x           850.0
#                                                    y           850.0
#                                                    likelihood  850.0
# ...
