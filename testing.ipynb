# %%
import pandas as pd
df = pd.read_csv("CollectedData_sha.csv")
df.head()
# Out:
#          scorer    Unnamed: 1    Unnamed: 2                sha  \
# 0     bodyparts           NaN           NaN                FR1
# 1        coords           NaN           NaN                  x
# 2  labeled-data  1-1_zRQbDkj4  img00070.png  828.9641728800706
# 3  labeled-data  1-1_zRQbDkj4  img00096.png  809.4548126598312
# 4  labeled-data  1-1_zRQbDkj4  img00256.png  804.1948060154176
#
#                 sha.1              sha.2               sha.3  \
# 0                 FR1                FR2                 FR2
# 1                   y                  x                   y
# 2   61.47902186275746  857.4489447744216  140.74099582964743
# 3   24.55059001730433  829.5784301740797  104.50932684920292
# 4  141.97946417288006  817.8179577909767  197.71053961834957
#
#                sha.4               sha.5              sha.6  ...  \
# 0                FG1                 FG1                FG2  ...
# 1                  x                   y                  x  ...
# ...
